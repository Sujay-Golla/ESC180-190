# %%
def make_schools(file_name):
    lines = []
    with open(file_name, 'r', encoding="utf-8") as file:
        lines = [line.strip() for line in file if line.strip()]
    """
    with open(file_name, 'r') as file:
        lines = file.readlines()
        for line in lines:
            lines.append(line.strip())
    print(len(lines))
    """
    schools = {}
    isName = False

    for i in range(len(lines)):
        if lines[i].isupper():
            isName = True
        elif isName and lines[i] != "\n":
            school = lines[i]
            if school in schools.keys():
                schools[school] += 1
            else:
                schools[school] = 1
        elif lines[i] == "\n":
            isName = False

    return topschools(schools)



def topschools(schools):
    L = schools.items()
    new_L = []
    for i in L:
        j = list(i)
        j[0], j[1] = j[1], j[0]
        k = tuple(j)
        new_L.append(k)

    return sorted(new_L)


print(make_schools("results.txt"))
# Out:
# [(1, 'Abbey Park H.S.'), (1, 'Aberdeen Hall Preparatory School'), (1, 'Agincourt C.I.'), (1, 'Alexander Mackenzie H.S.'), (1, 'Amity Int’l School'), (1, 'Applewood Heights S.S.'), (1, 'Ashbury College'), (1, 'Athol Murray Col-Notre Dame'), (1, 'Aurora H.S.'), (1, 'BIT School of Computer Science'), (1, 'Bangalore, –'), (1, 'Beijing World Youth Academy'), (1, 'Bell High School'), (1, 'Bluevale C.I.'), (1, 'Blyth Academy Waterloo'), (1, 'Burnaby Central S.S.'), (1, 'Burnaby South S.S.'), (1, 'Cambridge, ON'), (1, 'Cameron Heights C.I.'), (1, 'Canterbury H.S.'), (1, 'Cedarview M.S.'), (1, 'Centennial C. and V.I.'), (1, 'Changshu, –'), (1, 'Charlottetown, PE'), (1, 'Cheongna Dalton School'), (1, 'Cobequid Educational Centre'), (1, 'Cochrane H.S.'), (1, 'Cochrane, AB'), (1, 'Coll. Andre Grasset'), (1, 'College Marie de France'), (1, 'Colombo 8, –'), (1, 'Colonel By S.S.'), (1, 'Colonel Gray Sr. H.S'), (1, 'Crofton House School'), (1, 'David Suzuki S.S.'), (1, 'Delhi Public School-Navi Mumbai'), (1, 'Delta, BC'), (1, 'Deran Academy'), (1, 'Donald A. Wilson S.S.'), (1, 'Dr. Charles Best S.S.'), (1, 'E.S. Etienne-Brule'), (1, 'EEC Notre-Dame-de-Grace'), (1, 'Ecole Salish Secondary'), (1, 'Erindale S.S.'), (1, 'Forest Hill C.I.'), (1, 'Fort Richmond C.I.'), (1, 'Fraser Heights S.S.'), (1, 'Fredericton H.S.'), (1, 'Fredericton, NB'), (1, 'Georges Vanier S.S.'), (1, 'German Swiss International School'), (1, 'Gleneagle S.S.'), (1, 'Glenlyon Norfolk School'), (1, 'Gloucester, ON'), (1, 'Grandview Heights School'), (1, 'Guangdong Shunde Desheng School'), (1, 'Guelph, ON'), (1, 'Halifax West H.S.'), (1, 'Halifax, NS'), (1, 'Harrison Trimble H.S.'), (1, 'Harry Ainlay H.S.'), (1, 'Hillfield-Strathallan Coll. H.S.'), (1, 'Holy Cross Elementary School'), (1, 'Holy Trinity School'), (1, 'InGenius STEAM Education'), (1, 'Incheon, –'), (1, 'Ivy Collegiate School'), (1, 'J.H. Bruns C.I.'), (1, 'John McCrae S.S.'), (1, 'Kanata, ON'), (1, 'King City, ON'), (1, 'Kitsilano S.S. (English)'), (1, 'Lahore, –'), (1, 'Lakefield College School'), (1, 'Lakefield, ON'), (1, 'Langley Fundamental M. and S. Sch.'), (1, 'Langley, BC'), (1, 'Langstaff S.S.'), (1, 'Lanzhou Country Garden School'), (1, 'Lanzhou, –'), (1, 'Lisgar C.I.'), (1, 'Magee S.S.'), (1, 'Maktab'), (1, 'Maple H.S.'), (1, 'Maple Hill School'), (1, 'Maple, ON'), (1, 'Markham District H.S.'), (1, 'Middlefield C.I.'), (1, 'Moncton, NB'), (1, 'Mount Douglas S.S.'), (1, 'Mumbai, –'), (1, 'Navi Mumbai, –'), (1, 'New Delhi, –'), (1, 'Newmarket H.S.'), (1, 'Newmarket, ON'), (1, 'Noida, –'), (1, 'North Toronto C.I.'), (1, 'North Toronto Christian School'), (1, 'North York Academy'), (1, 'Okanagan Mission S.S.'), (1, 'Old Scona Academic H.S.'), (1, 'Our Lady of Mount Carmel'), (1, 'PATH2AI Learning'), (1, 'Philadelphia, PA'), (1, 'Port Perry H.S.'), (1, 'Port Perry, ON'), (1, 'PrepaTec en Cuernavaca'), (1, 'Primoris Academy'), (1, 'Prince of Wales S.S.'), (1, 'Proof School'), (1, 'Riverdale C.I.'), (1, 'Riverview Rural H.S.'), (1, 'Rockcliffe, ON'), (1, 'Rockway Mennonite C.I.'), (1, 'Royal St. George’s College'), (1, 'Russell, ON'), (1, 'SAIL Secondary School'), (1, 'Sacred Heart H.S.'), (1, 'Sammamish Chinese School'), (1, 'Sammamish, WA'), (1, 'San Diego, CA'), (1, 'San Francisco, CA'), (1, 'San Jose, CA'), (1, 'Saskatoon, SK'), (1, 'Seaquam S.S.'), (1, 'Seo-gu, –'), (1, 'Shanghai Songjiang Si Zhong Middle School'), (1, 'Shenzhen Col. of Inter. Education'), (1, 'Shenzhen Guangdong, –'), (1, 'Sinclair S.S.'), (1, 'Sir Frederick Banting S.S.'), (1, 'Sir Winston Churchill H.S.'), (1, 'St Joseph’s Preparatory School'), (1, 'St. Benedict C.S.S.'), (1, 'St. David C.S.S.'), (1, 'St. Ignatius Of Loyola Catholic S.S.'), (1, 'St. John’s-Ravenscourt School'), (1, 'St. Josephine Virtual High School'), (1, 'St. Michael’s Choir School'), (1, 'St. Thomas More C.I.'), (1, 'St.Paul’s College'), (1, 'Stonehill International School'), (1, 'Streetsville S.S.'), (1, 'SuZhou City, –'), (1, 'Suzhou XiangCheng High School'), (1, ...
